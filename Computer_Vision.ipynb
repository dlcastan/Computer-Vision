# %% [markdown]
# ## Computer Vision con Hugging Face
#
# **Autor:** Diego Lopez Castan
#
# **URL:** https://diegolopezcastan.com/

# %%
# Instalar librerías
# !pip install transformers
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 40.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 15.6 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 17.6 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
# Generación pipeline
clasificacion_imagenes = pipeline(task="image-classification")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 5dca96d (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
# Clasificación imágenes
clasificacion_imagenes("./foto.jpg")
# Out:
# [{'score': 0.9950246214866638, 'label': 'orange'},
#  {'score': 0.0031387147027999163, 'label': 'lemon'},
#  {'score': 0.00020812150614801794, 'label': 'strawberry'},
#  {'score': 0.00019934157899115235, 'label': 'banana'},
#  {'score': 0.00014797429321333766,
#   'label': 'grocery store, grocery, food market, market'}]
